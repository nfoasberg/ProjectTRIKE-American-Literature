# %%
import re
from re import findall

# %%
infile = open('1999_readable.txt')
metadata = infile.read()
print(metadata)
# Out:
# Title:
# 'A Mixture of Delicious and Freak': The Queer Fiction of Carson McCullers
# Authors:
# Adams, Rachel
# Source:
# American Literature: A Journal of Literary History, Criticism, and Bibliography (AL) 1999 Sept; 71 (3): 551-83.  [Journal Detail]
# Peer Reviewed:
# Yes
# ISSN:
# 0002-9831
# 1527-2117 (electronic)
# General Subject Areas:
# Subject Literature: American literature
# Period: 1900-1999
# Primary Subject Author: McCullers, Carson (1917-1967)
# Primary Subject Work: The Member of the Wedding (1946); Clock without Hands (1961)
# Classification: novel
# Subject Terms:
# treatment of freak; homosexuality; relationship to social order
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Update Code: 199901
# Sequence Numbers: 1999-1-15145
# Electronic Access:
# http://muse.jhu.edu.queens.ezproxy.cuny.edu/journals/american_literature/v071/71.3adams_r.html
# Accession Number:
# 1999056869
# Copyright:
# ...

# %%
infile_period = re.findall(r"Period\W+\S+",metadata)
for entry in infile_period:
    print(entry)
# Out:
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899
# Period: 1500-1599
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899
# Period: 1700-1799
# Period: 1900-1999
# Period: 1800-1899
# Period: 1900-1999
# Period: 1800-1899
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999

# %%
infile_author = re.findall(r"Primary Subject Author\W+\S+\s+\S+\s+\S+",metadata)
for entry in infile_author:
    print(entry)
# Out:
# Primary Subject Author: McCullers, Carson (1917-1967)
# Primary Subject Author: Momaday, N. Scott
# Primary Subject Author: Melville, Herman (1819-1891)
# Primary Subject Author: More, Sir Thomas
# Primary Subject Author: James, Henry, Jr.
# Primary Subject Author: Hildreth, Richard (1807-1865)
# Primary Subject Author: Gilman, Caroline Howard
# Primary Subject Author: Holmes, Oliver Wendell
# Primary Subject Author: Stein, Gertrude (1874-1946)
# Primary Subject Author: Alcott, Louisa May
# Primary Subject Author: Fuller, Margaret (1810-1850)
# Primary Subject Author: London, John Griffith
# Primary Subject Author: O'Hara, Frank (1926-1966)
# Primary Subject Author: Yamamoto, Hisaye (1921-)
# Primary Subject Author: Ginsberg, Allen (1926-1997)
# Primary Subject Author: James, Henry, Jr.
# Primary Subject Author: Wheatley, Phillis (1753?-1784)
# Primary Subject Author: Cisneros, Sandra (1954-)
# Primary Subject Author: Jewett, Sarah Orne
# ...

# %%
infile_work = re.findall(r"Primary Subject Work\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+",metadata)
for entry in infile_work:
    print(entry)
# Out:
# Primary Subject Work: The Member of the Wedding
# Primary Subject Work: The Way to Rainy Mountain
# Primary Subject Work: 'The Two Temples'
# Classification: short
# Primary Subject Work: Utopia (1516)
# Classification: prose
# Subject
# Primary Subject Work: 'The Impressions of a Cousin';
# Primary Subject Work: The Slave (1836)
# Classification: novel
# Primary Subject Work: and Commonwealth v. Aves (1836)
# Primary Subject Work: Recollections of a Southern Matron
# Primary Subject Work: Elsie Venner (1861)
# Classification: novel
# Primary Subject Work: 'Lifting Belly'
# Classification: poetry
# Subject
# Primary Subject Work: Little Women (1868); 'The Freak
# Primary Subject Work: Love of Life (1907); Martin
# Primary Subject Work: 'Pearl Harbor'
# Classification: poetry
# Subject
# Primary Subject Work: 'A Fire in Fontana'
# Classification:
# Primary Subject Work: 'Kaddish'; 'Howl'
# Classification: poetry
# Subject
# Primary Subject Work: The Turn of the Screw
# ...

# %%
infile_classification = re.findall(r"Classification\W+\S+\s+\S+\s+",metadata)
for entry in infile_classification:
    print(entry)
# Out:
# Classification: novel
# Subject
# Classification: fiction
# Subject
# Classification: short story
#
# Classification: prose
# Subject
# Classification: short story
#
# Classification: novel
# Primary
# Classification: novel
# Subject
# Classification: poetry
# Subject
# Classification: novel
# Subject
# Classification: prose
# Subject
# Classification: short story
#
# Classification: poetry
# Subject
# Classification: prose
# Subject
# Classification: poetry
# Subject
# Classification: fiction
# Subject
# Classification: poetry
# Subject
# Classification: short story
#
# Classification: short story
#
# Classification: novel
# Subject
# Classification: novel
# Subject
# Classification: poetry
# Subject
# Classification: novel
# Subject
# Classification: novel
# Subject

# %%
infile_terms = re.findall(r"Subject Terms:\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\S+\s+\S+\s+\S+\s+\S+\s+\S+",metadata)
for entry in infile_terms:
    print(entry)
# Out:
# Subject Terms:
# treatment of freak; homosexuality; relationship to social order
# Document Information:
# Publication Type: Journal Article
# Subject Terms:
# treatment of trickster; organic memory; of Native Americans; compared to Vizenor, Gerald Robert (1934-);
# Subject Terms:
# treatment of populism; social class; relationship to riots; at Astor Place Opera House (1849)
# Subject Terms:
# treatment of colonialism; in New World; compared to Hakluyt, Richard (1553?-1616)
# Document Information:
# Publication
# Subject Terms:
# treatment of inheritance; last will and testament; relationship to James, Henry, Sr. (1811-1882)
# Document
# Subject Terms:
# treatment of jurisdiction; of slavery; geography
# Document Information:
# Publication Type: Journal Article
# Language of
# Subject Terms:
# treatment of diseases; as contagion; especially puerperal fever
# Document Information:
# Publication Type: Journal Article
# Subject Terms:
# polysemy; of poetic language
# ...

# %%
infile_title = re.findall(r"Title:\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\S+\s+\S+",metadata)
for entry in infile_title:
    print(entry)
# Out:
# Title:
# 'A Mixture of Delicious and Freak': The Queer Fiction of Carson
# Title:
# Class Acts: The Astor Place Riots and Melville's 'The Two Temples'
# Title:
# Economy, Ecology, and Utopia in Early Colonial Promotional Literature
# Authors:
# Sweet,
# Title:
# Heir of Propriety: Inheritance, 'The Impressions of a Cousin,' and the
# Title:
# Judging Jurisdictions: Geography and Race in Slave Law and Literature of
# Title:
# Killing Them Softly: Childbed Fever and the Novel
# Authors:
# Thrailkill, Jane
# Title:
# Lifting Bellies, Filling Petunias, and Making Meaning through the Trans-Poetic
# Authors:
# Title:
# Louisa May Alcott's Queer Geniuses
# Authors:
# Stadler, Gustavus
# Source:
# American Literature:
# Title:
# Margaret Fuller, Body and Soul
# Authors:
# Davis, Cynthia J.
# Source:
# American
# Title:
# Nobody's Renown: Plagiarism and Publicity in the Career of Jack London
# Title:
# 'Our Country's Black and White Past': Film and the Figures of
# Title:
# ...

# %%
infile_article_author = re.findall(r"Authors:\W+\S+\s+\S+",metadata)
for entry in infile_article_author:
    print(entry)
# Out:
# Authors:
# Adams, Rachel
# Authors:
# Allen, Chadwick
# Authors:
# Berthold, Dennis
# Authors:
# Sweet, Timothy
# Authors:
# Adams, Richard
# Authors:
# Macdonald, Christine
# Authors:
# Thrailkill, Jane
# Authors:
# Holbrook, Susan
# Authors:
# Stadler, Gustavus
# Authors:
# Davis, Cynthia
# Authors:
# Glass, Loren
# Authors:
# Goble, Mark
# Authors:
# Hong, Grace
# Authors:
# Trigilio, Tony
# Authors:
# Matheson, Neill
# Authors:
# Wilcox, Kirstin
# Authors:
# Brady, Mary
# Authors:
# Shannon, Laurie
# Authors:
# Cowart, David
# Authors:
# Otten, Thomas
# Authors:
# Keller, Lynn
# Authors:
# Nowlin, Michael
# Authors:
# Haenni, Sabine

# %%
infile.close()

# %%
infile2 = open('1969_readable.txt')
metadata = infile2.read()
print(metadata)
# Out:
# Record: 1
# Title:
# A Dante-Parallel in Hemingway's 'A Way You'll Never Be'
# Authors:
# Yokelson, Joseph
# Source:
# American Literature: A Journal of Literary History, Criticism, and Bibliography (Durham, NC) 1969; 41: 279-280.
# ISSN:
# 0002-9831
# General Subject Areas:
# Subject Literature: American literature
# Period: 1900-1999
# Primary Subject Author: Hemingway, Ernest (1899-1961)
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Update Code: 196901
# Sequence Numbers: 1969-1-7386a
# Accession Number:
# 196917386a
# Copyright:
# Â© 2018 Modern Language Association
# Persistent link to this record (Permalink):
# http://search.ebscohost.com.queens.ezproxy.cuny.edu/login.aspx?direct=true&db=mzh&AN=196917386a&site=ehost-live
# Cut and Paste:
# <A href="http://search.ebscohost.com.queens.ezproxy.cuny.edu/login.aspx?direct=true&db=mzh&AN=196917386a&site=ehost-live">A Dante-Parallel in Hemingway's 'A Way You'll Never Be'</A>
# ...

# %%
infile2_title = re.findall(r"Title:\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\S+\s+\S+\s+\S+\s+\S+",metadata)
for entry in infile2_title:
    print(entry)
# Out:
# Title:
# A Dante-Parallel in Hemingway's 'A Way You'll Never Be'
# Authors:
# Yokelson, Joseph
# Source:
# Title:
# A Look into The Glass Mountain
# Authors:
# Simmons, Michael K.
# Source:
# American Literature:
# Title:
# A Note on John Crowe Ransom and Robert Penn Warren
# Authors:
# Justus, James
# Title:
# A Note on the Evolution of Robert Lowell's 'The Public Garden'
# Authors:
# Nelson,
# Title:
# A 'Scottish Cooper' for an 'American Scott'
# Authors:
# Walker, Warren S.
# Source:
# American
# Title:
# Another Broadside into Mardi
# Authors:
# Ellis, Theodore R., III
# Source:
# American Literature: A
# Title:
# Another Source for Hawthorne's 'Egotism; or, the Bosom Serpent'
# Authors:
# Harding, Walter
# Source:
# Title:
# Articles on American Literature Appearing in Current Periodicals
# Authors:
# Hollis, C. Carroll, comp.;
# Title:
# Conservatism and Criticism: The Literary Standards of American Whigs, 1845-1852
# Authors:
# Mulqueen, James
# Title:
# ...

# %%
infile_article_author = re.findall(r"Authors:\W+\S+\s+\S+",metadata)
for entry in infile_article_author:
    print(entry)
# Out:
# Authors:
# Yokelson, Joseph
# Authors:
# Simmons, Michael
# Authors:
# Justus, James
# Authors:
# Nelson, Rudolph
# Authors:
# Walker, Warren
# Authors:
# Ellis, Theodore
# Authors:
# Harding, Walter
# Authors:
# Hollis, C.
# Authors:
# Mulqueen, James
# Authors:
# Franklin, Rosemary
# Authors:
# Salzman, Jack
# Authors:
# Thomas, Owen
# Authors:
# Winn, James
# Authors:
# Abel, Darrel
# Authors:
# Martin, Robert
# Authors:
# Swennes, Robert
# Authors:
# Stern, Madeleine
# Authors:
# Rees, Robert
# Authors:
# Simpson, Eleanor
# Authors:
# Spofford, William
# Authors:
# Rowland, Beryl
# Authors:
# Patrick, Walton
# Authors:
# McClary, Ben
# Authors:
# Kligerman, Jack
# Authors:
# Thompson, G.
# Authors:
# Habegger, Alfred
# Authors:
# Hollis, C.
# Authors:
# Joyner, Nancy
# Authors:
# Ballowe, James
# Authors:
# Towers, Tom
# Authors:
# Spencer, Benjamin
# Authors:
# Katope, Christopher
# Authors:
# Gilkes, Lillian
# Authors:
# Bazzanella, Dominic
# Authors:
# Cumpiano, Marion
# ...

# %%
infile2_period = re.findall(r"Period\W+\S+",metadata)
for entry in infile2_period:
    print(entry)
# Out:
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1600-1699
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1700-1799
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899

# %%
infile2_subject_author = re.findall(r"Primary Subject Author\W+\S+\s+\S+\s+\S+",metadata)
for entry in infile2_subject_author:
    print(entry)
# Out:
# Primary Subject Author: Hemingway, Ernest (1899-1961)
# Primary Subject Author: Beach, Joseph Warren
# Primary Subject Author: Warren, Robert Penn
# Primary Subject Author: Lowell, Robert (1917-1977)
# Primary Subject Author: Cooper, James Fenimore
# Primary Subject Author: Melville, Herman (1819-1891)
# Primary Subject Author: Hawthorne, Nathaniel (1804-1864)
# Primary Subject Author: Eliot, T. S.
# Primary Subject Author: Dreiser, Theodore (1871-1945);
# Primary Subject Author: Dickinson, Emily (1830-1886)
# Primary Subject Author: role of Dickinson,
# Primary Subject Author: Faulkner, William (1897-1962)
# Primary Subject Author: Hawthorne, Nathaniel (1804-1864)
# Primary Subject Author: James, Henry, Jr.
# Primary Subject Author: Child, Lydia Maria
# Primary Subject Author: Clemens, Samuel (1835-1910)
# Primary Subject Author: Clemens, Samuel (1835-1910)
# Primary Subject Author: Melville, Herman (1819-1891)
# Primary Subject Author: Melville, Herman (1819-1891)
# ...

# %%
infile2_subject_work = re.findall(r"Primary Subject Work\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+",metadata)
for entry in infile2_subject_work:
    print(entry)
# Out:
# Primary Subject Work: The Glass Mountain
# Classification: novel
# Subject Terms:
# treatment of
# Primary Subject Work: All the King's Men (1946)
# Classification: novel
# Subject Terms:
# Primary Subject Work: Mardi (1849)
# Classification: novel
# Subject Terms:
# treatment in burlesque;
# Primary Subject Work: in The American Whig Review (1845-1852)
# Subject Terms:
# role
# Primary Subject Work: 'The Turning Point of My Life'
# Classification: prose
# Subject
# Primary Subject Work: 'The Paradise of Bachelors and the Tartarus of Maids'
# Primary Subject Work: 'Bartleby the Scrivener'
# Classification: short story
# Subject Terms:
# allusion;
# Primary Subject Work: The Spy (1821); The Pilot (1823)
# Classification: novel
# Primary
# Primary Subject Work: A Boy's Town (1890)
# Classification: autobiography
# Subject Terms:
# treatment
# Primary Subject Work: Sister Carrie (1900)
# Classification: novel
# Subject Terms:
# sources in
# ...

# %%
mylist = ["1800-1899; classical literature; American literature; Lowell, James Russell; poetry; prose",
"1800-1899; American literature; Ingraham, Joseph Holt",
"1800-1899; Stuart, Robert; American literature; Irving, Washington; Astoria; prose; 'Manuscript Journal'",
"1800-1899; American literature; Melville, Herman",
"1900-1999; bibliography; American literature",
"1800-1899; American literature; James, Henry, Jr.",
"1800-1899; American literature; Emerson, Ralph Waldo",
"1800-1899; textual errors; chapters; American literature; James, Henry, Jr.; The Ambassadors; novel",
"1900-1999; bibliography; American literature",
"1800-1899; periodicals; social reform; muckrakers; American literature; The Arena; Flower, Benjamin Orange",
"1800-1899; periodicals; American literature; Overland Monthly; Harte, Bret","
"1900-1999; Philippe, Charles-Louis; Eliot, T. S.; English literature; 'Preludes'; 'Rhapsody on a Windy Night'; poetry; Bubu de Montparnasse; Marie Donadieu; French literature; novel
"1800-1899; literary career; canon; biographical information; American literature; Cranch, Christopher Pearse; poetry; prose"]
# Out:
#   File "<ipython-input-99-5877a2c78548>", line 11
#     "1800-1899; periodicals; American literature; Overland Monthly; Harte, Bret","
#                                                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
records_1950 = open('1950_readable.txt')
metadata = records_1950.read()
print(metadata)
# Out:
# Record: 1
# Title:
# A Glance at Lowell's Classical Reading
# Authors:
# Pritchard, John Paul
# Source:
# American Literature: A Journal of Literary History, Criticism, and Bibliography (AL) 1950 Jan; 21 (4): 442-55.  [Journal Detail]
# Peer Reviewed:
# Yes
# ISSN:
# 0002-9831
# 1527-2117 (electronic)
# General Subject Areas:
# Subject Literature: American literature
# Period: 1800-1899
# Primary Subject Author: Lowell, James Russell (1819-1891)
# Classification: poetry; and prose
# Subject Terms:
# sources in classical literature
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Update Code: 000001
# Sequence Numbers: 0000-1-26421
# Accession Number:
# 0000100312
# Copyright:
# Â© 2018 Modern Language Association
# Persistent link to this record (Permalink):
# http://search.ebscohost.com.queens.ezproxy.cuny.edu/login.aspx?direct=true&db=mzh&AN=0000100312&site=ehost-live
# Cut and Paste:
# ...

# %%
records_1950_period = re.findall(r"Period\W+\S+",metadata)
for entry in records_1950_period:
    print(entry)
# Out:
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1700-1799
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1600-1699
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1700-1799
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899

# %%
records_1950_subject_author = re.findall(r"Primary Subject Author\W+\S+\s+\S+\s+\S+",metadata)
for entry in records_1950_subject_author:
    print(entry)
# Out:
# Primary Subject Author: Lowell, James Russell
# Primary Subject Author: Ingraham, Joseph Holt
# Primary Subject Author: Irving, Washington (1783-1859)
# Primary Subject Author: Melville, Herman (1819-1891)
# Primary Subject Author: James, Henry, Jr.
# Primary Subject Author: Emerson, Ralph Waldo
# Primary Subject Author: James, Henry, Jr.
# Primary Subject Author: role of Flower,
# Primary Subject Author: role of Harte,
# Primary Subject Author: Eliot, T. S.
# Primary Subject Author: Philippe, Charles-Louis (1874-1909)
# Primary Subject Author: Cranch, Christopher Pearse
# Primary Subject Author: Melville, Herman (1819-1891)
# Primary Subject Author: Emerson, Ralph Waldo
# Primary Subject Author: Franklin, Benjamin (1706-1790)
# Primary Subject Author: Dwight, John Sullivan
# Primary Subject Author: Longfellow, Henry Wadsworth
# Primary Subject Author: Holmes, Oliver Wendell
# Primary Subject Author: treatment in Clemens,
# Primary Subject Author: Clemens, Samuel (1835-1910)
# ...

# %%
records_1950_subject_work = re.findall(r"Primary Subject Work\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+",metadata)
for entry in records_1950_subject_work:
    print(entry)
# Out:
# Primary Subject Work: Astoria (1836)
# Classification: prose
# Subject Terms:
# sources
# Primary Subject Work: The Ambassadors (1903)
# Classification: novel
# Subject Terms:
# Primary Subject Work: The Arena (1889-1909)
# Primary Subject Author: role
# Primary Subject Work: Overland Monthly
# Primary Subject Author: role of
# Primary Subject Work: 'Preludes'; 'Rhapsody on a Windy Night'
# Classification:
# Primary Subject Work: Bubu de Montparnasse; Marie Donadieu
# Classification: novel
# Primary Subject Work: The Song of Hiawatha (1855)
# Classification: poetry
# Primary Subject Work: Kalevala
# Subject Terms:
# influence on Longfellow, Henry
# Primary Subject Work: The Autocrat of the Breakfast Table (1858)
# Primary Subject Work: Roughing It (1872)
# Classification: prose
# Subject Terms:
# Primary Subject Work: Billy Budd
# Classification: novel
# Subject Terms:
# irony;
# Primary Subject Work: The Confidence-Man (1857)
# Classification: novel
# Subject Terms:
# ...

# %%
records_1950_classification = re.findall(r"Classification\W+\S+\s+\S+\s+\S+",metadata)
for entry in records_1950_classification:
    print(entry)
# Out:
# Classification: poetry; and prose
# Classification: prose
# Subject Terms:
# Classification: novel
# Subject Terms:
# Classification: poetry
# Subject Terms:
# Classification: novel
# Subject Terms:
# Classification: poetry; and prose
# Classification: prose
# Subject Terms:
# Classification: translation
# Subject Terms:
# Classification: poetry
# Subject Terms:
# Classification: prose
# Primary Subject
# Classification: prose
# Subject Terms:
# Classification: novel
# Subject Terms:
# Classification: novel
# Subject Terms:
# Classification: novel
# Subject Terms:
# Classification: prose; manuscript notes;
# Classification: short story
# Subject
# Classification: novel
# Subject Terms:
# Classification: criticism
# Subject Terms:
# Classification: prose
# Subject Terms:
# Classification: prose; manuscript notes

# %%
records_1950_terms = re.findall(r"Subject Terms:\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\S+\s+\S+\s+\S+\s+\S+\s+\S+",metadata)
for entry in records_1950_terms:
    print(entry)
# Out:
# Subject Terms:
# sources in classical literature
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Subject Terms:
# sources in Stuart, Robert; 'Manuscript Journal'
# Document Information:
# Publication Type: Journal Article
# Language of
# Subject Terms:
# bibliography
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Update Code: 195001
# Subject Terms:
# relationship to textual errors; in chapters
# Document Information:
# Publication Type: Journal Article
# Language of
# Subject Terms:
# bibliography
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Update Code: 195001
# Subject Terms:
# relationship to social reform; muckrakers
# Document Information:
# Publication Type: Journal Article
# Language of Publication:
# Subject Terms:
# sources in Philippe, Charles-Louis (1874-1909); Bubu de Montparnasse; Marie Donadieu
# General Subject Areas:
# ...

# %%
records_1980 = open('1980_readable.txt')
metadata = records_1980.read()
print(metadata)
# Out:
# Record: 1
# Title:
# A Source for Irving's 'The Young Italian'
# Authors:
# Clark, Michael
# Source:
# American Literature: A Journal of Literary History, Criticism, and Bibliography (AL) 1980 Mar; 52 (1): 111-14.  [Journal Detail]
# Peer Reviewed:
# Yes
# ISSN:
# 0002-9831
# 1527-2117 (electronic)
# General Subject Areas:
# Subject Literature: American literature
# Period: 1800-1899
# Primary Subject Author: Irving, Washington (1783-1859)
# Primary Subject Work: 'The Story of the Young Italian'
# Classification: short story
# Subject Terms:
# sources in Allston, Washington (1779-1843); Monaldi (1841)
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Update Code: 000001
# Sequence Numbers: 0000-1-25723
# Accession Number:
# 0000100723
# Copyright:
# Â© 2018 Modern Language Association
# Persistent link to this record (Permalink):
# ...

# %%
records_1980_period = re.findall(r"Period\W+\S+",metadata)
for entry in records_1980_period:
    print(entry)
# Out:
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1700-1799
# Period: 1800-1899
# Period: 1700-1799
# Period: 1600-1699
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1600-1699
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999

# %%
records_1980_subject_author = re.findall(r"Primary Subject Author\W+\S+\s+\S+\s+\S+",metadata)
for entry in records_1980_subject_author:
    print(entry)
# Out:
# Primary Subject Author: Irving, Washington (1783-1859)
# Primary Subject Author: Lincoln, Abraham (1809-1865)
# Primary Subject Author: Hawthorne, Nathaniel (1804-1864)
# Primary Subject Author: Cable, George Washington
# Primary Subject Author: Dickinson, Emily (1830-1886)
# Primary Subject Author: Hawthorne, Nathaniel (1804-1864)
# Primary Subject Author: Faulkner, William (1897-1962)
# Primary Subject Author: Steinbeck, John (1902-1968)
# Primary Subject Author: Chopin, Kate (1851-1904)
# Primary Subject Author: Ibsen, Henrik (1828-1906)
# Primary Subject Author: and Wagner, Richard
# Primary Subject Author: Jefferson, Thomas (1743-1826)
# Primary Subject Author: Hawthorne, Nathaniel (1804-1864)
# Primary Subject Author: Wheatley, Phillis (1753?-1784)
# Primary Subject Author: Taylor, Edward (ca.
# Primary Subject Author: Whitman, Walt (1819-1892)
# Primary Subject Author: Clemens, Samuel (1835-1910)
# Primary Subject Author: Frost, Robert (1874-1963)
# ...

# %%
records_1980_subject_work = re.findall(r"Primary Subject Work\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+",metadata)
for entry in records_1980_subject_work:
    print(entry)
# Out:
# Primary Subject Work: 'The Story of the Young Italian'
# Classification:
# Primary Subject Work: 'The Hollow of the Three Hills'; 'Alice
# Primary Subject Work: The Grandissimes (1880)
# Classification: novel
# Subject Terms:
# Primary Subject Work: 'I like to see it lap the
# Primary Subject Work: 'Roger Malvin's Burial'
# Classification: short story
# Subject
# Primary Subject Work: 'The Bear'
# Classification: short story
# Subject Terms:
# Primary Subject Work: In Dubious Battle (1936)
# Classification: novel
# Subject
# Primary Subject Work: 'Mrs. Mobry's Reason'
# Classification: short story
# Subject
# Primary Subject Work: Gengangere (1881) [Ghosts]
# Classification: drama
# Primary Subject
# Primary Subject Work: Der Ring des Nibelungen (1869-1876)
# Subject Terms:
# Primary Subject Work: Notes on the State of Virginia (1787)
# Primary Subject Work: The Scarlet Letter (1850)
# Classification: novel
# Subject
# Primary Subject Work: Preparatory Meditations (1682-1725)
# ...

# %%
records_1980_classification = re.findall(r"Classification\W+\S+\s+\S+\s+\S+",metadata)
for entry in records_1980_classification:
    print(entry)
# Out:
# Classification: short story
# Subject
# Classification: prose
# Subject Terms:
# Classification: short story
# Subject
# Classification: novel
# Subject Terms:
# Classification: poetry
# Subject Terms:
# Classification: short story
# Subject
# Classification: short story
# Subject
# Classification: novel
# Subject Terms:
# Classification: short story
# Subject
# Classification: drama
# Primary Subject
# Classification: prose
# Subject Terms:
# Classification: novel
# Subject Terms:
# Classification: poetry
# Group: by
# Classification: poetry
# Group: by
# Classification: poetry
# Subject Terms:
# Classification: prose
# Subject Terms:
# Classification: prose; and letters
# Classification: poetry
# Subject Terms:
# Classification: short story
# Subject
# Classification: novel
# Subject Terms:
# Classification: novel
# Subject Terms:
# Classification: novel
# Subject Terms:
# Classification: poetry
# Subject Terms:
# Classification: poetry
# Primary Subject
# Classification: novel
# ...

# %%
records_1980_terms = re.findall(r"Subject Terms:\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\S+\s+\S+\s+\S+\s+\S+\s+\S+",metadata)
for entry in records_1980_terms:
    print(entry)
# Out:
# Subject Terms:
# sources in Allston, Washington (1779-1843); Monaldi (1841)
# Document Information:
# Publication Type: Journal Article
# Language
# Subject Terms:
# imagery
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Update Code: 000001
# Subject Terms:
# as personal narrative; treatment of Vietnam War; compared to Greene, Graham (1904-1991); The Quiet
# Subject Terms:
# Bibliography
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Update Code: 198001
# Subject Terms:
# imagery; treatment of evil
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Subject Terms:
# as comedy of manners
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Subject Terms:
# train imagery; poetic form; treatment of progress; technology
# Document Information:
# Publication Type: Journal Article
# Subject Terms:
# ...

# %%
records_2010 = open('2010_readable.txt')
metadata = records_2010.read()
print(metadata)
# Out:
# Record: 1
# Title:
# A Wayward Art: Battle-Pieces and Melville's Poetic Turn
# Authors:
# Marrs, Cody
# Source:
# American Literature: A Journal of Literary History, Criticism, and Bibliography (AL) 2010 Mar; 82 (1): 91-119.  [Journal Detail]
# Peer Reviewed:
# Yes
# ISSN:
# 0002-9831
# 1527-2117 (electronic)
# General Subject Areas:
# Subject Literature: American literature
# Period: 1800-1899
# Primary Subject Author: Melville, Herman (1819-1891)
# Primary Subject Work: Battle Pieces and Aspects of War (1866)
# Classification: poetry
# Subject Terms:
# poetic structure; treatment of American Civil War; relationship to literary career
# Document Information:
# Publication Type: Journal Article
# Language of Publication: English
# Update Code: 201001
# Sequence Numbers: 2010-1-11700
# Electronic Access:
# DOI: 10.1215/00029831-2009-070
# Accession Number:
# 2010380638
# Copyright:
# Â© 2018 Modern Language Association
# Persistent link to this record (Permalink):
# ...

# %%
records_2010_period = re.findall(r"Period\W+\S+",metadata)
for entry in records_2010_period:
    print(entry)
# Out:
# Period: 1800-1899
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1800-1899
# Period: 1900-1999
# Period: 1700-1799
# Period: 1800-1899
# Period: 1900-1999
# Period: 1800-1899
# Period: role
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999
# Period: 1900-1999
# Period: 1800-1899

# %%
records_2010_subject_author = re.findall(r"Primary Subject Author\W+\S+\s+\S+\s+\S+",metadata)
for entry in records_2010_subject_author:
    print(entry)
# Out:
# Primary Subject Author: Melville, Herman (1819-1891)
# Primary Subject Author: Schuyler, George Samuel
# Primary Subject Author: Stowe, Harriet Beecher
# Primary Subject Author: Emerson, Ralph Waldo
# Primary Subject Author: Yezierska, Anzia (1885-1970)
# Primary Subject Author: Cable, George Washington
# Primary Subject Author: Douglass, Frederick (1817-1895)
# Primary Subject Author: Douglass, Frederick (1817-1895)
# Primary Subject Author: Melville, Herman (1819-1891)
# Primary Subject Author: Toomer, Jean (1894-1967)
# Primary Subject Author: Wheatley, Phillis (1753?-1784)
# Primary Subject Author: Jacobs, Harriet Ann
# Primary Subject Author: Wright, Richard (1908-1960)
# Primary Subject Author: Coke, Allison Adelle
# Primary Subject Author: Carson, Rachel (1907-1964)
# Primary Subject Author: Lin Yutang (1895-1976)
# Primary Subject Author: Apess, William (1798-1839)

# %%
records_1980_subject_work = re.findall(r"Primary Subject Work\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+",metadata)
for entry in records_1980_subject_work:
    print(entry)
# Out:
# Primary Subject Work: Battle Pieces and Aspects of War (1866)
# Primary Subject Work: Black Empire (1936-38)
# Classification: fiction
# Subject Terms:
# Primary Subject Work: Uncle Tom's Cabin (1852)
# Classification: novel
# Subject
# Primary Subject Work: Hungry Hearts (1920); 'Wings'; Salome of the
# Primary Subject Work: The Grandissimes (1880)
# Classification: novel
# Subject Terms:
# Primary Subject Work: My Bondage and My Freedom (1855)
# Classification:
# Primary Subject Work: Redburn (1849)
# Classification: novel
# Subject Terms:
# narrator;
# Primary Subject Work: Cane (1923)
# Classification: short story
# Group: by
# Primary Subject Work: Poems on Various Subjects, Religious and Moral
# Primary Subject Work: Incidents in the Life of a Slave
# Primary Subject Work: Native Son (1940); Black Power (1954)
# Classification:
# Primary Subject Work: Blood Run (2006)
# Classification: poetry; poetic cycle
# Primary Subject Work: The Sea around Us (1951)
# ...

# %%
records_2010_classification = re.findall(r"Classification\W+\S+\s+\S+\s+\S+",metadata)
for entry in records_2010_classification:
    print(entry)
# Out:
# Classification: poetry
# Subject Terms:
# Classification: fiction
# Subject Terms:
# Classification: novel
# Subject Terms:
# Classification: prose
# Subject Terms:
# Classification: short story
# Group:
# Classification: novel
# Subject Terms:
# Classification: prose
# Group: by
# Classification: autobiography
# Group: by
# Classification: novel
# Subject Terms:
# Classification: short story
# Group:
# Classification: poetry
# Group: by
# Classification: autobiography
# Group: by
# Classification: novel
# Group: by
# Classification: poetry; poetic cycle
# Classification: prose
# Primary Subject
# Classification: prose
# Group: by
# Classification: in United States
# Classification: prose
# Group: by

# %%
records_2010_terms = re.findall(r"Subject Terms:\W+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\s+\S+\S+\s+\S+\s+\S+\s+\S+\s+\S+",metadata)
for entry in records_2010_terms:
    print(entry)
# Out:
# Subject Terms:
# poetic structure; treatment of American Civil War; relationship to literary career
# Document Information:
# Publication
# Subject Terms:
# treatment of black identity; empire; internationalism; relationship to Italo-Ethiopian War (1935-1936); African American press
# Subject Terms:
# poetic voice; treatment of fugitive slaves; American Civil War; relationship to circulation
# Document Information:
# Subject Terms:
# treatment of death; children; innocence; outsider; relationship to moral instruction; Puritanism; compared to Janeway,
# Subject Terms:
# metaphor; of electricity; treatment of eloquence; human body; Sumner, Charles (1811-1874); relationship to telegraph;
# Subject Terms:
# treatment of violence; relationship to secularism; Brown, John (1800-1859); abolitionist movement; terrorism; Islam
# Document
# Subject Terms:
# treatment of female body; aesthetics; cultural assimilation; in film adaptation
# General Subject Areas:
# Literature
# Subject Terms:
# ...

# %%
subject_authors_1950 = '''
Primary Subject Author: Lowell, James Russell
Primary Subject Author: Ingraham, Joseph Holt
Primary Subject Author: Irving, Washington (1783-1859)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: James, Henry, Jr.
Primary Subject Author: Emerson, Ralph Waldo
Primary Subject Author: James, Henry, Jr.
Primary Subject Author: role of Flower,  Benjamin Orange (1858-1918)
Primary Subject Author: role of Harte, Bret (1836-1902)
Primary Subject Author: Eliot, T. S. (1888-1965)
Primary Subject Author: Philippe, Charles-Louis (1874-1909)
Primary Subject Author: Cranch, Christopher Pearse (1813-1892)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: Emerson, Ralph Waldo (1803-1882)
Primary Subject Author: Franklin, Benjamin (1706-1790)
Primary Subject Author: Dwight, John Sullivan (1813-1893)
Primary Subject Author: Longfellow, Henry Wadsworth (1807-1882)
Primary Subject Author: Holmes, Oliver Wendell (1809-1894)
Primary Subject Author: treatment in Clemens, Samuel (1835-1910)
Primary Subject Author: Clemens, Samuel (1835-1910)
Primary Subject Author: Poe, Edgar Allan (1809-1849)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: Cotton, John (1584-1652)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: Whittier, John Greenleaf
Primary Subject Author: Whitman, Walt (1819-1892)
Primary Subject Author: Hawthorne, Nathaniel (1804-1864)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: Cather, Willa (1873-1947)
Primary Subject Author: Dwight, Timothy (1752-1817)
Primary Subject Author: Flint, Timothy (1780-1840)
Primary Subject Author: Channing, William Ellery, the Elder (1780-1842)
Tocqueville, Alexis-Henri-Charles-Maurice-Clérel, comte de (1805-1859)
Primary Subject Author: Whitman, Walt (1819-1892)'''

# %%
neat_authors_1950 = subject_authors_1950.split("Primary Subject Author:")
for author in neat_authors_1950:
    print(author)
# Out:
#  Lowell, James Russell
#
#  Ingraham, Joseph Holt
#
#  Irving, Washington (1783-1859)
#
#  Melville, Herman (1819-1891)
#
#  James, Henry, Jr.
#
#  Emerson, Ralph Waldo
#
#  James, Henry, Jr.
#
#  role of Flower,  Benjamin Orange (1858-1918)
#
#  role of Harte, Bret (1836-1902)
#
#  Eliot, T. S. (1888-1965)
#
#  Philippe, Charles-Louis (1874-1909)
#
#  Cranch, Christopher Pearse (1813-1892)
#
#  Melville, Herman (1819-1891)
#
#  Emerson, Ralph Waldo (1803-1882)
#
#  Franklin, Benjamin (1706-1790)
#
#  Dwight, John Sullivan (1813-1893)
#
#  Longfellow, Henry Wadsworth (1807-1882)
#
#  Holmes, Oliver Wendell (1809-1894)
#
#  treatment in Clemens, Samuel (1835-1910)
#
#  Clemens, Samuel (1835-1910)
#
#  Poe, Edgar Allan (1809-1849)
#
#  Melville, Herman (1819-1891)
#
#  Melville, Herman (1819-1891)
#
#  Melville, Herman (1819-1891)
#
#  Cotton, John (1584-1652)
#
#  Melville, Herman (1819-1891)
#
#  Whittier, John Greenleaf
#
#  Whitman, Walt (1819-1892)
#
# ...

# %%
subject_authors_1980 = '''Primary Subject Author
Primary Subject Author: Irving, Washington (1783-1859)
Primary Subject Author: Lincoln, Abraham (1809-1865)
Primary Subject Author: Hawthorne, Nathaniel (1804-1864)
Primary Subject Author: Cable, George Washington
Primary Subject Author: Dickinson, Emily (1830-1886)
Primary Subject Author: Hawthorne, Nathaniel (1804-1864)
Primary Subject Author: Faulkner, William (1897-1962)
Primary Subject Author: Steinbeck, John (1902-1968)
Primary Subject Author: Chopin, Kate (1851-1904)
Primary Subject Author: Ibsen, Henrik (1828-1906)
Primary Subject Author: and Wagner, Richard (1813-1883)
Primary Subject Author: Jefferson, Thomas (1743-1826)
Primary Subject Author: Hawthorne, Nathaniel (1804-1864)
Primary Subject Author: Wheatley, Phillis (1753?-1784)
Primary Subject Author: Taylor, Edward (ca. 1644-1729)
Primary Subject Author: Whitman, Walt (1819-1892)
Primary Subject Author: Clemens, Samuel (1835-1910)
Primary Subject Author: Frost, Robert (1874-1963)
Primary Subject Author: Lowell, Robert (1917-1977)
Primary Subject Author: Anderson, Sherwood (1876-1941)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: Chopin, Kate (1851-1904)
Primary Subject Author: Flaubert, Gustave (1821-1880)
Primary Subject Author: Dickey, James (1923-1997)
Primary Subject Author: Tompson, Benjamin (1642-1714)
Primary Subject Author: treatment of Metacom, Chief of the Wampanoags (ca. 1637-1676)
Primary Subject Author: Faulkner, William (1897-1962)
Primary Subject Author: Cooper, James Fenimore (1789-1851)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: Warren, Robert Penn (1905-1989)
Primary Subject Author: Hemingway, Ernest (1899-1961)
Primary Subject Author: Baldwin, James (1924-1987)
Primary Subject Author: Howells, William Dean (1837-1920)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: treatment in Thoreau, Henry David (1817-1862)
Primary Subject Author: Whitman, Walt (1819-1892)
Primary Subject Author: Porter, Katherine Anne (1890-1980)'''

# %%
neat_authors_1980 = subject_authors_1980.split("Primary Subject Author:")
for author in neat_authors_1980:
    print(author)
# Out:
# Primary Subject Author
#
#  Irving, Washington (1783-1859)
#
#  Lincoln, Abraham (1809-1865)
#
#  Hawthorne, Nathaniel (1804-1864)
#
#  Cable, George Washington
#
#  Dickinson, Emily (1830-1886)
#
#  Hawthorne, Nathaniel (1804-1864)
#
#  Faulkner, William (1897-1962)
#
#  Steinbeck, John (1902-1968)
#
#  Chopin, Kate (1851-1904)
#
#  Ibsen, Henrik (1828-1906)
#
#  and Wagner, Richard (1813-1883)
#
#  Jefferson, Thomas (1743-1826)
#
#  Hawthorne, Nathaniel (1804-1864)
#
#  Wheatley, Phillis (1753?-1784)
#
#  Taylor, Edward (ca. 1644-1729)
#
#  Whitman, Walt (1819-1892)
#
#  Clemens, Samuel (1835-1910)
#
#  Frost, Robert (1874-1963)
#
#  Lowell, Robert (1917-1977)
#
#  Anderson, Sherwood (1876-1941)
#
#  Melville, Herman (1819-1891)
#
#  Chopin, Kate (1851-1904)
#
#  Flaubert, Gustave (1821-1880)
#
#  Dickey, James (1923-1997)
#
#  Tompson, Benjamin (1642-1714)
#
#  treatment of Metacom, Chief of the Wampanoags (ca. 1637-1676)
#
#  Faulkner, William (1897-1962)
#
# ...

# %%
subject_authors_2010 = '''Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: Schuyler, George Samuel (1895-1977)
Primary Subject Author: Stowe, Harriet Beecher (1811-1896)
Primary Subject Author: Emerson, Ralph Waldo (1803-1882)
Primary Subject Author: Yezierska, Anzia (1885-1970)
Primary Subject Author: Cable, George Washington (1844-1925)
Primary Subject Author: Douglass, Frederick (1817-1895)
Primary Subject Author: Douglass, Frederick (1817-1895)
Primary Subject Author: Melville, Herman (1819-1891)
Primary Subject Author: Toomer, Jean (1894-1967)
Primary Subject Author: Wheatley, Phillis (1753?-1784)
Primary Subject Author: Jacobs, Harriet Ann (1813-1897)
Primary Subject Author: Wright, Richard (1908-1960)
Primary Subject Author: Coke, Allison Adelle Hedge (1958-)
Primary Subject Author: Carson, Rachel (1907-1964)
Primary Subject Author: Lin Yutang (1895-1976)
Primary Subject Author: Apess, William (1798-1839)'''

# %%
neat_authors_2010 = subject_authors_2010.split("Primary Subject Author: ")
for author in neat_authors_2010:
    print(author)
# Out:
# Melville, Herman (1819-1891)
#
# Schuyler, George Samuel (1895-1977)
#
# Stowe, Harriet Beecher (1811-1896)
#
# Emerson, Ralph Waldo (1803-1882)
#
# Yezierska, Anzia (1885-1970)
#
# Cable, George Washington (1844-1925)
#
# Douglass, Frederick (1817-1895)
#
# Douglass, Frederick (1817-1895)
#
# Melville, Herman (1819-1891)
#
# Toomer, Jean (1894-1967)
#
# Wheatley, Phillis (1753?-1784)
#
# Jacobs, Harriet Ann (1813-1897)
#
# Wright, Richard (1908-1960)
#
# Coke, Allison Adelle Hedge (1958-)
#
# Carson, Rachel (1907-1964)
#
# Lin Yutang (1895-1976)
#
# Apess, William (1798-1839)

# %%
subject_dates_1950 = '''Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1700-1799
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1600-1699
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1700-1799
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
'''

# %%
neat_dates_1950 = subject_dates_1950.split("Period: ")
for date in neat_dates_1950:
    print(date)
# Out:
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1700-1799
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1600-1699
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1700-1799
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899

# %%
subject_dates_1980 = '''Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1700-1799
Period: 1800-1899
Period: 1700-1799
Period: 1600-1699
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1900-1999
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1600-1699
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1900-1999
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
'''

# %%
neat_dates_1980 = subject_dates_1980.split("Period: ")
for date in neat_dates_1980:
    print(date)
# Out:
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1700-1799
#
# 1800-1899
#
# 1700-1799
#
# 1600-1699
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1900-1999
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1600-1699
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1900-1999
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999

# %%
subject_dates_2010 = '''Period: 1800-1899
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1800-1899
Period: 1900-1999
Period: 1700-1799
Period: 1800-1899
Period: 1900-1999
Period: 1800-1899
Period: role of Child, Lydia Maria (1802-1880); in editions (1865)
Period: 1900-1999
Period: 1900-1999
Period: 1900-1999
Period: 1900-1999
Period: 1900-1999
Period: 1900-1999
Period: 1800-1899
'''

# %%
neat_dates_2010 = subject_dates_2010.split("Period: ")
for date in neat_dates_2010:
    print (date)
# Out:
# 1800-1899
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1800-1899
#
# 1900-1999
#
# 1700-1799
#
# 1800-1899
#
# 1900-1999
#
# 1800-1899
#
# role of Child, Lydia Maria (1802-1880); in editions (1865)
#
# 1900-1999
#
# 1900-1999
#
# 1900-1999
#
# 1900-1999
#
# 1900-1999
#
# 1900-1999
#
# 1800-1899

# %%
subject_work_1950 = '''Primary Subject Work: Astoria (1836)
Primary Subject Work: The Ambassadors (1903)
Primary Subject Work: The Arena (1889-1909)
Primary Subject Work: Overland Monthly
Primary Subject Work: 'Preludes'; 'Rhapsody on a Windy Night'
Primary Subject Work: 'Rhapsody on a Windy Night'
Primary Subject Work: Bubu de Montparnasse; Marie Donadieu
Primary Subject Work: The Song of Hiawatha (1855)
Primary Subject Work: Kalevala
Primary Subject Work: The Autocrat of the Breakfast Table (1858)
Primary Subject Work: Roughing It (1872)
Primary Subject Work: Billy Budd
Primary Subject Work: The Confidence-Man (1857)
Primary Subject Work: 'The Gentle Boy'
Primary Subject Work: Pierre (1852)
Primary Subject Work: Remarks on American Literature (1830)
Primary Subject Work: La DÃ©mocratie en AmÃ©rique (1835-40)
'''

# %%
neat_work_1950 = subject_work_1950.split("Primary Subject Work: ")
for work in neat_work_1950:
    print(work)
# Out:
# Astoria (1836)
#
# The Ambassadors (1903)
#
# The Arena (1889-1909)
#
# Overland Monthly
#
# 'Preludes'; 'Rhapsody on a Windy Night'
#
# 'Rhapsody on a Windy Night'
#
# Bubu de Montparnasse; Marie Donadieu
#
# The Song of Hiawatha (1855)
#
# Kalevala
#
# The Autocrat of the Breakfast Table (1858)
#
# Roughing It (1872)
#
# Billy Budd
#
# The Confidence-Man (1857)
#
# 'The Gentle Boy'
#
# Pierre (1852)
#
# Remarks on American Literature (1830)
#
# La DÃ©mocratie en AmÃ©rique (1835-40)

# %%
subject_work_1980 = '''Primary Subject Work: 'The Story of the Young Italian'
Primary Subject Work: 'The Hollow of the Three Hills'; 'Alice Doane's Appeal'
Primary Subject Work: The Grandissimes (1880)
Primary Subject Work: 'I like to see it lap the miles'
Primary Subject Work: 'Roger Malvin's Burial'
Primary Subject Work: 'The Bear'
Primary Subject Work: In Dubious Battle (1936)
Primary Subject Work: 'Mrs. Mobry's Reason'
Primary Subject Work: Gengangere (1881) [Ghosts]
Primary Subject Work: Der Ring des Nibelungen (1869-1876)
Primary Subject Work: Notes on the State of Virginia (1787)
Primary Subject Work: The Scarlet Letter (1850)
Primary Subject Work: Preparatory Meditations (1682-1725)
Primary Subject Work: The Innocents Abroad (1869); Roughing It (1872)
Primary Subject Work: Winesburg, Ohio (1919)
Primary Subject Work: The Awakening (1899)
Primary Subject Work: Madame Bovary (1857)
Primary Subject Work: 'The Firebombing'
Primary Subject Work: New-Englands Crisis (1676)
Primary Subject Work: The Sound and the Fury (1929)
Primary Subject Work: The Last of the Mohicans (1826)
Primary Subject Work: The Confidence-Man (1857)
Primary Subject Work: All the King's Men (1946)
Primary Subject Work: For Whom the Bell Tolls (1940)
Primary Subject Work: Go Tell It on the Mountain (1953)
Primary Subject Work: The World of Chance (1893)
Primary Subject Work: Typee (1846)
Primary Subject Work: Leaves of Grass (1855)
Primary Subject Work: Hacienda (1934); 'The Children of Xochitl'
'''

# %%
neat_work_1980 = subject_work_1980.split("Primary Subject Work: ")
for work in neat_work_1980:
    print(work)
# Out:
# 'The Story of the Young Italian'
#
# 'The Hollow of the Three Hills'; 'Alice Doane's Appeal'
#
# The Grandissimes (1880)
#
# 'I like to see it lap the miles'
#
# 'Roger Malvin's Burial'
#
# 'The Bear'
#
# In Dubious Battle (1936)
#
# 'Mrs. Mobry's Reason'
#
# Gengangere (1881) [Ghosts]
#
# Der Ring des Nibelungen (1869-1876)
#
# Notes on the State of Virginia (1787)
#
# The Scarlet Letter (1850)
#
# Preparatory Meditations (1682-1725)
#
# The Innocents Abroad (1869); Roughing It (1872)
#
# Winesburg, Ohio (1919)
#
# The Awakening (1899)
#
# Madame Bovary (1857)
#
# 'The Firebombing'
#
# New-Englands Crisis (1676)
#
# The Sound and the Fury (1929)
#
# The Last of the Mohicans (1826)
#
# The Confidence-Man (1857)
#
# All the King's Men (1946)
#
# For Whom the Bell Tolls (1940)
#
# Go Tell It on the Mountain (1953)
#
# The World of Chance (1893)
#
# Typee (1846)
#
# Leaves of Grass (1855)
#
# Hacienda (1934); 'The Children of Xochitl'

# %%
subject_work_2010 = '''Primary Subject Work: Battle Pieces and Aspects of War (1866)
Primary Subject Work: Black Empire (1936-38)
Primary Subject Work: Uncle Tom's Cabin (1852)
Primary Subject Work: Hungry Hearts (1920); 'Wings'; Salome of the Tenements (1922)
Primary Subject Work: The Grandissimes (1880)
Primary Subject Work: My Bondage and My Freedom (1855)
Primary Subject Work: Redburn (1849)
Primary Subject Work: Cane (1923)
Primary Subject Work: Poems on Various Subjects, Religious and Moral (1773)
Primary Subject Work: Incidents in the Life of a Slave Girl (1861)
Primary Subject Work: Native Son (1940); Black Power (1954)
Primary Subject Work: Blood Run (2006)
Primary Subject Work: The Sea around Us (1951)
Primary Subject Work: in The New Yorker
Primary Subject Work: Eulogy on King Philip (1836)
'''

# %%
neat_work_2010 = subject_work_2010.split("Primary Subject Work: ")
for work in neat_work_2010:
    print(work)
# Out:
# Battle Pieces and Aspects of War (1866)
#
# Black Empire (1936-38)
#
# Uncle Tom's Cabin (1852)
#
# Hungry Hearts (1920); 'Wings'; Salome of the Tenements (1922)
#
# The Grandissimes (1880)
#
# My Bondage and My Freedom (1855)
#
# Redburn (1849)
#
# Cane (1923)
#
# Poems on Various Subjects, Religious and Moral (1773)
#
# Incidents in the Life of a Slave Girl (1861)
#
# Native Son (1940); Black Power (1954)
#
# Blood Run (2006)
#
# The Sea around Us (1951)
#
# in The New Yorker
#
# Eulogy on King Philip (1836)

# %%
subject_work_classification_1950 = '''Classification: poetry; and prose
Classification: prose
Classification: novel
Classification: poetry
Classification: novel
Classification: poetry; and prose
Classification: prose
Classification: translation
Classification: poetry
Classification: prose
Classification: prose
Classification: novel
Classification: novel
Classification: novel
Classification: prose; manuscript notes; source study
Classification: short story
Classification: novel
Classification: criticism
Classification: prose
Classification: prose; manuscript notes
'''

# %%
neat_work_classification_1950 = subject_work_classification_1950.split("Classification: ")
for work in neat_work_classification_1950:
    print(work)
# Out:
# poetry; and prose
#
# prose
#
# novel
#
# poetry
#
# novel
#
# poetry; and prose
#
# prose
#
# translation
#
# poetry
#
# prose
#
# prose
#
# novel
#
# novel
#
# novel
#
# prose; manuscript notes; source study
#
# short story
#
# novel
#
# criticism
#
# prose
#
# prose; manuscript notes

# %%
subject_work_classification_1980 = '''Classification: short story
Classification: prose
Classification: short story
Classification: novel
Classification: poetry
Classification: short story
Classification: short story
Classification: novel
Classification: short story
Classification: drama
Classification: prose
Classification: novel
Classification: poetry
Classification: poetry
Classification: poetry
Classification: prose
Classification: prose; and letters
Classification: poetry
Classification: short story
Classification: novel
Classification: novel
Classification: novel
Classification: poetry
Classification: poetry
Classification: novel
Classification: novel
Classification: novel
Classification: novel
Classification: novel
Classification: novel
Classification: novel
Classification: novel
Classification: poetry
Classification: novel
'''

# %%
neat_work_classification_1980 = subject_work_classifications_1980.split("Classification: ")
for work in neat_work_classification_1980:
    print(work)
# Out:
# poetry; and prose
#
# prose
#
# novel
#
# poetry
#
# novel
#
# poetry; and prose
#
# prose
#
# translation
#
# poetry
#
# prose
#
# prose
#
# novel
#
# novel
#
# novel
#
# prose; manuscript notes; source study
#
# short story
#
# novel
#
# criticism
#
# prose
#
# prose; manuscript note

# %%
subject_work_classification_2010 = '''Classification: poetry
Classification: fiction
Classification: novel
Classification: prose
Classification: short story
Classification: novel
Classification: prose
Classification: autobiography
Classification: novel
Classification: short story
Classification: poetry
Classification: autobiography
Classification: novel
Classification: poetry; poetic cycle
Classification: prose
Classification: prose
Classification: in United States
Classification: prose'''

# %%
neat_work_classification_2010 = subject_work_classification_2010.split('Classification: ')
for work in neat_work_classification_2010:
    print(work)
# Out:
# poetry
#
# fiction
#
# novel
#
# prose
#
# short story
#
# novel
#
# prose
#
# autobiography
#
# novel
#
# short story
#
# poetry
#
# autobiography
#
# novel
#
# poetry; poetic cycle
#
# prose
#
# prose
#
# in United States
#
# prose

# %%
subject_terms_1950 = '''sources in classical literature
sources in Stuart, Robert; 'Manuscript Journal'
bibliography
relationship to textual errors; in chapters
bibliography
relationship to social reform; muckrakers
sources in Philippe, Charles-Louis (1874-1909); Bubu de Montparnasse; Marie Donadieu
relationship to literary career; canon; includes biographical information
relationship to mysticism
English language translation; of German Romantic writers
on English language translation; by Dwight, John Sullivan (1813-1893)
sources in Kalevala
influence on Longfellow, Henry Wadsworth (1807-1882); The Song of Hiawatha (1855)
treatment in lecture; includes edition
irony; treatment in criticism
tone; in anecdote
bibliography
treatment in book review; in religious periodicals (1846-1849)
treatment of Pearson, Tobias (character); relationship to ambiguity; in narrative structure; compared to Glendinning, Pierre (character); in Melville, Herman (1819-1891); Pierre (1852)
treatment of romantic love; of characters
on democracy; relationship to literary production; influence on Tocqueville, Alexis-Henri-Charles-Maurice-ClÃ©rel, comte de (1805-1859); La
treatment of democracy; relationship to literary production; sources in Channing, William Ellery, the Elder
treatment of oratory
'''

# %%
subject_terms_primary_list_1950 = subject_terms_1950.split("/n")
for term in subject_terms_primary_list_1950:
    print(term)
# Out:
# sources in classical literature
# sources in Stuart, Robert; 'Manuscript Journal'
# bibliography
# relationship to textual errors; in chapters
# bibliography
# relationship to social reform; muckrakers
# sources in Philippe, Charles-Louis (1874-1909); Bubu de Montparnasse; Marie Donadieu
# relationship to literary career; canon; includes biographical information
# relationship to mysticism
# English language translation; of German Romantic writers
# on English language translation; by Dwight, John Sullivan (1813-1893)
# sources in Kalevala
# influence on Longfellow, Henry Wadsworth (1807-1882); The Song of Hiawatha (1855)
# treatment in lecture; includes edition
# irony; treatment in criticism
# tone; in anecdote
# bibliography
# treatment in book review; in religious periodicals (1846-1849)
# treatment of Pearson, Tobias (character); relationship to ambiguity; in narrative structure; compared to Glendinning, Pierre (character); in Melville, Herman (1819-1891); Pierre (1852)
# ...

# %%
subject_terms_split_1950 = '''sources in classical literature
sources in Stuart, Robert; 'Manuscript Journal'
bibliography
relationship to textual errors; in chapters
bibliography
relationship to social reform; muckrakers
sources in Philippe, Charles-Louis (1874-1909); Bubu de Montparnasse; Marie Donadieu
relationship to literary career; canon; includes biographical information
relationship to mysticism
English language translation; of German Romantic writers
on English language translation; by Dwight, John Sullivan (1813-1893)
sources in Kalevala
influence on Longfellow, Henry Wadsworth (1807-1882); The Song of Hiawatha (1855)
treatment in lecture; includes edition
irony; treatment in criticism
tone; in anecdote
bibliography
treatment in book review; in religious periodicals (1846-1849)
treatment of Pearson, Tobias (character); relationship to ambiguity; in narrative structure; compared to Glendinning, Pierre (character); in Melville, Herman (1819-1891); Pierre (1852)
treatment of romantic love; of characters
on democracy; relationship to literary production; influence on Tocqueville, Alexis-Henri-Charles-Maurice-ClÃ©rel, comte de (1805-1859); La
treatment of democracy; relationship to literary production; sources in Channing, William Ellery, the Elder
treatment of oratory'''

# %%
subject_terms_list_1950 = subject_terms_split_1950.split("; ")
for term in subject_terms_list_1950:
    print(term)
# Out:
# sources in classical literature
# sources in Stuart, Robert
# 'Manuscript Journal'
# bibliography
# relationship to textual errors
# in chapters
# bibliography
# relationship to social reform
# muckrakers
# sources in Philippe, Charles-Louis (1874-1909)
# Bubu de Montparnasse
# Marie Donadieu
# relationship to literary career
# canon
# includes biographical information
# relationship to mysticism
# English language translation
# of German Romantic writers
# on English language translation
# by Dwight, John Sullivan (1813-1893)
# sources in Kalevala
# influence on Longfellow, Henry Wadsworth (1807-1882)
# The Song of Hiawatha (1855)
# treatment in lecture
# includes edition
# irony
# treatment in criticism
# tone
# in anecdote
# bibliography
# treatment in book review
# in religious periodicals (1846-1849)
# treatment of Pearson, Tobias (character)
# relationship to ambiguity
# in narrative structure
# compared to Glendinning, Pierre (character)
# in Melville, Herman (1819-1891)
# ...

# %%
subject_terms_1980 = '''sources in Allston, Washington (1779-1843); Monaldi (1841)
imagery
as personal narrative; treatment of Vietnam War; compared to Greene, Graham (1904-1991); The Quiet American (1955)
Bibliography
imagery; treatment of evil
as comedy of manners
train imagery; poetic form; treatment of progress; technology
symbolism; of oak tree
sources in Hemingway, Ernest (1899-1961); For Whom the Bell Tolls (1940)
treatment of labor strike; of farmers; in California
thematic structure; sources in Ibsen, Henrik (1828-1906); Gengangere (1881) [Ghosts]; Wagner, Richard (1813-1883); Der Ring des Nibelungen (1869-1876)
thematic structure; influence on Chopin, Kate (1851-1904); 'Mrs. Mobry's Reason'
relationship to literary culture
narrative technique; relationship to oral tradition
role of classicism
rhetorical technique; relationship to praise; spirituality; of authorial self
as dialogue
realism; in narrative style; relationship to truth; context; of storytelling
treatment of poetics
role of apprenticeship; with New Critics
treatment of the ordinary; in daily life; of characters; sources in Joyce, James (1882-1941); Dubliners (1914)
narrative structure; genre conventions; of travel literature
sea imagery; treatment of Romantic imagination; political crisis; of female protagonist; sources in Flaubert, Gustave (1821-1880); Madame Bovary (1857)
sea imagery; treatment of Romantic imagination; political crisis; of female protagonist; influence on Chopin, Kate (1851-1904); The Awakening (1899)
persona
King Philip's War
narration; by Compson, Quentin (character)
plot; relationship to American history; civilization
narrative technique; treatment of hatred; of Native Americans
treatment of Stark, Willie (character); as Long, Huey Pierce (1893-1935); relationship to historical events
as tragic novel; relationship to narrative form
setting; symbolism; of city; treatment of spiritual growth; of protagonist
self-parody; treatment of romantic idealism; of protagonist; relationship to Hawthorne, Nathaniel (1804-1864)
relationship to Middle Ages
imagery; of happiness; despair; treatment of Xochiquetzal; sources in Mexican legend
treatment of Xochiquetzal; relationship to imagery; of happiness; despair; in Porter, Katherine Anne (1890-1980); Hacienda (1934); 'The Children of Xochitl'
'''

# %%
subject_terms_first_list_1980 = subject_terms_1980.split("/n")
for term in subject_terms_first_list_1980:
    print(term)
# Out:
# sources in Allston, Washington (1779-1843); Monaldi (1841)
# imagery
# as personal narrative; treatment of Vietnam War; compared to Greene, Graham (1904-1991); The Quiet American (1955)
# Bibliography
# imagery; treatment of evil
# as comedy of manners
# train imagery; poetic form; treatment of progress; technology
# symbolism; of oak tree
# sources in Hemingway, Ernest (1899-1961); For Whom the Bell Tolls (1940)
# treatment of labor strike; of farmers; in California
# thematic structure; sources in Ibsen, Henrik (1828-1906); Gengangere (1881) [Ghosts]; Wagner, Richard (1813-1883); Der Ring des Nibelungen (1869-1876)
# thematic structure; influence on Chopin, Kate (1851-1904); 'Mrs. Mobry's Reason'
# relationship to literary culture
# narrative technique; relationship to oral tradition
# role of classicism
# rhetorical technique; relationship to praise; spirituality; of authorial self
# as dialogue
# realism; in narrative style; relationship to truth; context; of storytelling
# ...

# %%
subject_terms_first_list_1980 = '''sources in Allston, Washington (1779-1843); Monaldi (1841)
imagery
as personal narrative; treatment of Vietnam War; compared to Greene, Graham (1904-1991); The Quiet American (1955)
Bibliography
imagery; treatment of evil
as comedy of manners
train imagery; poetic form; treatment of progress; technology
symbolism; of oak tree
sources in Hemingway, Ernest (1899-1961); For Whom the Bell Tolls (1940)
treatment of labor strike; of farmers; in California
thematic structure; sources in Ibsen, Henrik (1828-1906); Gengangere (1881) [Ghosts]; Wagner, Richard (1813-1883); Der Ring des Nibelungen (1869-1876)
thematic structure; influence on Chopin, Kate (1851-1904); 'Mrs. Mobry's Reason'
relationship to literary culture
narrative technique; relationship to oral tradition
role of classicism
rhetorical technique; relationship to praise; spirituality; of authorial self
as dialogue
realism; in narrative style; relationship to truth; context; of storytelling
treatment of poetics
role of apprenticeship; with New Critics
treatment of the ordinary; in daily life; of characters; sources in Joyce, James (1882-1941); Dubliners (1914)
narrative structure; genre conventions; of travel literature
sea imagery; treatment of Romantic imagination; political crisis; of female protagonist; sources in Flaubert, Gustave (1821-1880); Madame Bovary (1857)
sea imagery; treatment of Romantic imagination; political crisis; of female protagonist; influence on Chopin, Kate (1851-1904); The Awakening (1899)
persona
King Philip's War
narration; by Compson, Quentin (character)
plot; relationship to American history; civilization
narrative technique; treatment of hatred; of Native Americans
treatment of Stark, Willie (character); as Long, Huey Pierce (1893-1935); relationship to historical events
as tragic novel; relationship to narrative form
setting; symbolism; of city; treatment of spiritual growth; of protagonist
self-parody; treatment of romantic idealism; of protagonist; relationship to Hawthorne, Nathaniel (1804-1864)
relationship to Middle Ages
imagery; of happiness; despair; treatment of Xochiquetzal; sources in Mexican legend
treatment of Xochiquetzal; relationship to imagery; of happiness; despair; in Porter, Katherine Anne (1890-1980); Hacienda (1934); 'The Children of Xochitl'
'''

# %%
subject_terms_list_1980 = subject_terms_first_list_1980.split("; ")
for term in subject_terms_list_1980:
    print(term)
# Out:
# sources in Allston, Washington (1779-1843)
# Monaldi (1841)
# imagery
# as personal narrative
# treatment of Vietnam War
# compared to Greene, Graham (1904-1991)
# The Quiet American (1955)
# Bibliography
# imagery
# treatment of evil
# as comedy of manners
# train imagery
# poetic form
# treatment of progress
# technology
# symbolism
# of oak tree
# sources in Hemingway, Ernest (1899-1961)
# For Whom the Bell Tolls (1940)
# treatment of labor strike
# of farmers
# in California
# thematic structure
# sources in Ibsen, Henrik (1828-1906)
# Gengangere (1881) [Ghosts]
# Wagner, Richard (1813-1883)
# Der Ring des Nibelungen (1869-1876)
# thematic structure
# influence on Chopin, Kate (1851-1904)
# 'Mrs. Mobry's Reason'
# relationship to literary culture
# narrative technique
# relationship to oral tradition
# role of classicism
# rhetorical technique
# relationship to praise
# spirituality
# of authorial self
# as dialogue
# realism
# in narrative style
# relationship to truth
# ...

# %%
subject_terms_2010 = '''poetic structure; treatment of American Civil War; relationship to literary career
treatment of black identity; empire; internationalism; relationship to Italo-Ethiopian War (1935-1936); African American press
poetic voice; treatment of fugitive slaves; American Civil War; relationship to circulation
treatment of death; children; innocence; outsider; relationship to moral instruction; Puritanism; compared to Janeway, James (1636?-1674); A Token for Children (1671); Sherwood, Mary Martha Butt (1775-1851); 'Little Henry and His Bearer'
metaphor; of electricity; treatment of eloquence; human body; Sumner, Charles (1811-1874); relationship to telegraph; transnationalism; political conflict
treatment of violence; relationship to secularism; Brown, John (1800-1859); abolitionist movement; terrorism; Islam
treatment of female body; aesthetics; cultural assimilation; in film adaptation
treatment of female body; aesthetics; cultural assimilation; in film adaptation; of Yezierska, Anzia (1885-1970); Hungry Hearts (1920); 'Wings'; Salome of the Tenements (1922)
treatment of ethnic identity; relationship to literary dialect; phonograph
satire; ekphrasis; intertextuality; with Punch; treatment of slavery; relationship to abolitionist movement; caricature
treatment of ethnic identity; education; childhood; relationship to abolitionist movement; performance; black-white relations
narrator; political metaphor; treatment of urban space; national identity; relationship to expansionism; authorship
treatment of race; relationship to folk music
role of preface; authorship; relationship to publishing; trial; theories of Gates, Henry Louis, Jr. (1950-)
allegory; treatment of suffering; soldier; ruins; national identity; theories of Benjamin, Walter (1892-1940)
relationship to literary prizes; professionalism
relationship to sexual politics
chronotope; treatment of dreaming; relationship to postcolonialism; theories of Husserl, Edmund (1859-1938)
treatment of geometry; land
genre conventions; of speculative fiction; realist fiction; treatment of slavery; the past; trauma
treatment of World War I; national identity; citizen; relationship to political ideologies; internationalism
role of funding
treatment of ecology; relationship to urban life; compared to Jacobs, Jane (1916-2006); The Death
treatment of technology; relationship to typewriter; invention
rhetoric; treatment of colonization; racism; cultural survival; relationship to abolitionist movement
'''

# %%
subject_terms_first_list_2010 = subject_terms_2010.split("/n")
for term in subject_terms_first_list_2010:
    print(term)
# Out:
# poetic structure; treatment of American Civil War; relationship to literary career
# treatment of black identity; empire; internationalism; relationship to Italo-Ethiopian War (1935-1936); African American press
# poetic voice; treatment of fugitive slaves; American Civil War; relationship to circulation
# treatment of death; children; innocence; outsider; relationship to moral instruction; Puritanism; compared to Janeway, James (1636?-1674); A Token for Children (1671); Sherwood, Mary Martha Butt (1775-1851); 'Little Henry and His Bearer'
# metaphor; of electricity; treatment of eloquence; human body; Sumner, Charles (1811-1874); relationship to telegraph; transnationalism; political conflict
# treatment of violence; relationship to secularism; Brown, John (1800-1859); abolitionist movement; terrorism; Islam
# treatment of female body; aesthetics; cultural assimilation; in film adaptation
# ...

# %%
subject_terms_first_list_2010 = '''poetic structure; treatment of American Civil War; relationship to literary career
treatment of black identity; empire; internationalism; relationship to Italo-Ethiopian War (1935-1936); African American press
poetic voice; treatment of fugitive slaves; American Civil War; relationship to circulation
treatment of death; children; innocence; outsider; relationship to moral instruction; Puritanism; compared to Janeway, James (1636?-1674); A Token for Children (1671); Sherwood, Mary Martha Butt (1775-1851); 'Little Henry and His Bearer'
metaphor; of electricity; treatment of eloquence; human body; Sumner, Charles (1811-1874); relationship to telegraph; transnationalism; political conflict
treatment of violence; relationship to secularism; Brown, John (1800-1859); abolitionist movement; terrorism; Islam
treatment of female body; aesthetics; cultural assimilation; in film adaptation
treatment of female body; aesthetics; cultural assimilation; in film adaptation; of Yezierska, Anzia (1885-1970); Hungry Hearts (1920); 'Wings'; Salome of the Tenements (1922)
treatment of ethnic identity; relationship to literary dialect; phonograph
satire; ekphrasis; intertextuality; with Punch; treatment of slavery; relationship to abolitionist movement; caricature
treatment of ethnic identity; education; childhood; relationship to abolitionist movement; performance; black-white relations
narrator; political metaphor; treatment of urban space; national identity; relationship to expansionism; authorship
treatment of race; relationship to folk music
role of preface; authorship; relationship to publishing; trial; theories of Gates, Henry Louis, Jr. (1950-)
allegory; treatment of suffering; soldier; ruins; national identity; theories of Benjamin, Walter (1892-1940)
relationship to literary prizes; professionalism
relationship to sexual politics
chronotope; treatment of dreaming; relationship to postcolonialism; theories of Husserl, Edmund (1859-1938)
treatment of geometry; land
genre conventions; of speculative fiction; realist fiction; treatment of slavery; the past; trauma
treatment of World War I; national identity; citizen; relationship to political ideologies; internationalism
role of funding
treatment of ecology; relationship to urban life; compared to Jacobs, Jane (1916-2006); The Death
treatment of technology; relationship to typewriter; invention
rhetoric; treatment of colonization; racism; cultural survival; relationship to abolitionist movement'''

# %%
subject_terms_list_2010 = subject_terms_first_list_2010.split("; ")
for term in subject_terms_list_2010:
    print(term)
# Out:
# poetic structure
# treatment of American Civil War
# relationship to literary career
# treatment of black identity
# empire
# internationalism
# relationship to Italo-Ethiopian War (1935-1936)
# African American press
# poetic voice
# treatment of fugitive slaves
# American Civil War
# relationship to circulation
# treatment of death
# children
# innocence
# outsider
# relationship to moral instruction
# Puritanism
# compared to Janeway, James (1636?-1674)
# A Token for Children (1671)
# Sherwood, Mary Martha Butt (1775-1851)
# 'Little Henry and His Bearer'
# metaphor
# of electricity
# treatment of eloquence
# human body
# Sumner, Charles (1811-1874)
# relationship to telegraph
# transnationalism
# political conflict
# treatment of violence
# relationship to secularism
# Brown, John (1800-1859)
# abolitionist movement
# terrorism
# Islam
# treatment of female body
# aesthetics
# cultural assimilation
# in film adaptation
# treatment of female body
# aesthetics
# ...

# %%
subject_terms_first_list_2010 = '''poetic structure; treatment of American Civil War; relationship to literary career
treatment of black identity; empire; internationalism; relationship to Italo-Ethiopian War (1935-1936); African American press
poetic voice; treatment of fugitive slaves; American Civil War; relationship to circulation
treatment of death; children; innocence; outsider; relationship to moral instruction; Puritanism; compared to Janeway, James (1636?-1674); A Token for Children (1671); Sherwood, Mary Martha Butt (1775-1851); 'Little Henry and His Bearer'
metaphor; of electricity; treatment of eloquence; human body; Sumner, Charles (1811-1874); relationship to telegraph; transnationalism; political conflict
treatment of violence; relationship to secularism; Brown, John (1800-1859); abolitionist movement; terrorism; Islam
treatment of female body; aesthetics; cultural assimilation; in film adaptation
treatment of female body; aesthetics; cultural assimilation; in film adaptation; of Yezierska, Anzia (1885-1970); Hungry Hearts (1920); 'Wings'; Salome of the Tenements (1922)
treatment of ethnic identity; relationship to literary dialect; phonograph
satire; ekphrasis; intertextuality; with Punch; treatment of slavery; relationship to abolitionist movement; caricature
treatment of ethnic identity; education; childhood; relationship to abolitionist movement; performance; black-white relations
narrator; political metaphor; treatment of urban space; national identity; relationship to expansionism; authorship
treatment of race; relationship to folk music
role of preface; authorship; relationship to publishing; trial; theories of Gates, Henry Louis, Jr. (1950-)
allegory; treatment of suffering; soldier; ruins; national identity; theories of Benjamin, Walter (1892-1940)
relationship to literary prizes; professionalism
relationship to sexual politics
chronotope; treatment of dreaming; relationship to postcolonialism; theories of Husserl, Edmund (1859-1938)
treatment of geometry; land
genre conventions; of speculative fiction; realist fiction; treatment of slavery; the past; trauma
treatment of World War I; national identity; citizen; relationship to political ideologies; internationalism
role of funding
treatment of ecology; relationship to urban life; compared to Jacobs, Jane (1916-2006); The Death
treatment of technology; relationship to typewriter; invention
rhetoric; treatment of colonization; racism; cultural survival; relationship to abolitionist movement'''

# %%
subject_terms_list_2010 = subject_terms_first_list_2010.split("; ")
for term in subject_terms_list_2010:
    print(term)
# Out:
# poetic structure
# treatment of American Civil War
# relationship to literary career
# treatment of black identity
# empire
# internationalism
# relationship to Italo-Ethiopian War (1935-1936)
# African American press
# poetic voice
# treatment of fugitive slaves
# American Civil War
# relationship to circulation
# treatment of death
# children
# innocence
# outsider
# relationship to moral instruction
# Puritanism
# compared to Janeway, James (1636?-1674)
# A Token for Children (1671)
# Sherwood, Mary Martha Butt (1775-1851)
# 'Little Henry and His Bearer'
# metaphor
# of electricity
# treatment of eloquence
# human body
# Sumner, Charles (1811-1874)
# relationship to telegraph
# transnationalism
# political conflict
# treatment of violence
# relationship to secularism
# Brown, John (1800-1859)
# abolitionist movement
# terrorism
# Islam
# treatment of female body
# aesthetics
# cultural assimilation
# in film adaptation
# treatment of female body
# aesthetics
# ...

# %%
mystring = "remember that landscape of mine, for"
print(mystring[:13])
# Out:
# remember that
